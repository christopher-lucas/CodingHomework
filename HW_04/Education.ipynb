# %%
import os
import pandas as pd
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/christopher/Documents/Education/Coding Bootcamp/Git/Data_Class/CodingHomework'

# %%
cd ../..
# Out:
# /Users/christopher/Documents/Education/Coding Bootcamp/Git

# %%
os.getcwd()
# Out:
# '/Users/christopher/Documents/Education/Coding Bootcamp/Git'

# %%
cd ..
# Out:
# /Users/christopher/Documents/Education/Coding Bootcamp

# %%
cd Homework
# Out:
# /Users/christopher/Documents/Education/Coding Bootcamp/Homework

# %%
SchoolFile = os.path.join('04 Pandas', 'PyCitySchools', 'raw_data','schools_complete.csv')
StudentFile = os.path.join('04 Pandas', 'PyCitySchools', 'raw_data','students_complete.csv')
school_df = pd.read_csv(SchoolFile)
student_df = pd.read_csv(StudentFile)
school_df.rename(columns={'name': 'school_name', 'School ID' : 'school_id'}, inplace=True)
student_df.rename(columns={'school': 'school_name', 'Student ID' : 'student_id', 'name' : 'student_name'}, inplace=True)

# %%
school_df
# Out:
#     school_id            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
student_df
# Out:
#        student_id         student_name gender grade         school_name  \
# 0               0         Paul Bradley      M   9th   Huang High School
# 1               1         Victor Smith      M  12th   Huang High School
# 2               2      Kevin Rodriguez      M  12th   Huang High School
# 3               3    Dr. Richard Scott      M  12th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 7               7         Nicole Baker      F  12th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# ...

# %%
student_df.sort_values('student_name')
# Out:
#        student_id        student_name gender grade            school_name  \
# 36194       36194        Aaron Acosta      M  12th       Ford High School
# 9133         9133       Aaron Aguilar      M   9th  Hernandez High School
# 36126       36126      Aaron Anderson      M   9th       Ford High School
# 18861       18861      Aaron Atkinson      M   9th     Bailey High School
# 19812       19812        Aaron Bailey      M  12th     Bailey High School
# 17610       17610       Aaron Bonilla      M   9th    Cabrera High School
# 2737         2737        Aaron Booker      M  12th      Huang High School
# 8336         8336         Aaron Boyer      M   9th  Hernandez High School
# 5816         5816        Aaron Brandt      M  10th   Figueroa High School
# 35726       35726         Aaron Brown      M  12th       Ford High School
# 31033       31033         Aaron Burch      M  10th    Johnson High School
# 33466       33466         Aaron Burns      M  12th    Johnson High School
# ...

# %%
grouped_reading_score = ed_df.groupby('reading_score')

# %%
grouped_reading_score.count()
# Out:
#                school_id  school_name  type  size  budget  student_id  name  \
# reading_score
# 63                   751          751   751   751     751         751   751
# 64                   738          738   738   738     738         738   738
# 65                   758          758   758   758     758         758   758
# 66                   743          743   743   743     743         743   743
# 67                   714          714   714   714     714         714   714
# 68                   746          746   746   746     746         746   746
# 69                  1110         1110  1110  1110    1110        1110  1110
# 70                  1110         1110  1110  1110    1110        1110  1110
# 71                  1073         1073  1073  1073    1073        1073  1073
# 72                  1120         1120  1120  1120    1120        1120  1120
# 73                  1112         1112  1112  1112    1112        1112  1112
# ...

# %%
grouped_reading_score.mean()
# Out:
#                school_id         size        budget    student_id  math_score
# reading_score
# 63              7.026631  4060.351531  2.610852e+06  19757.078562   77.038615
# 64              7.094851  4030.390244  2.588789e+06  19966.379404   76.627371
# 65              6.960422  4046.799472  2.600998e+06  19550.394459   77.006596
# 66              7.091521  4050.814266  2.604697e+06  19958.004038   77.433378
# 67              6.872549  3992.088235  2.566469e+06  19283.116246   76.613445
# 68              7.239946  4059.890080  2.609111e+06  20180.183646   77.908847
# 69              6.936937  3189.962162  2.020129e+06  19438.456757   79.511712
# 70              7.070270  3207.245045  2.033130e+06  19812.327928   79.574775
# 71              6.900280  3221.517241  2.041640e+06  19427.931966   79.505126
# 72              6.820536  3233.325893  2.050403e+06  19151.328571   79.473214
# 73              7.286871  3233.689748  2.051009e+06  20340.456835   79.468525
# ...

# %%
grouped_reading_scor.iloc[0:3,0:4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-63f3a1c4d86e> in <module>()
# ----> 1 grouped_reading_scor.iloc[0:3,0:4]
#
# NameError: name 'grouped_reading_scor' is not defined
