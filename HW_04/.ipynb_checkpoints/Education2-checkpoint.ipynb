# %%
import os
import pandas as pd
import numpy as np

# %%
SchoolFile = os.path.join('04 Pandas', 'PyCitySchools', 'raw_data','schools_complete.csv')
StudentFile = os.path.join('04 Pandas', 'PyCitySchools', 'raw_data','students_complete.csv')
school_df = pd.read_csv(SchoolFile)
student_df = pd.read_csv(StudentFile)
school_df.rename(columns={'name': 'school_name', 'School ID' : 'school_id'}, inplace=True)
student_df.rename(columns={'school': 'school_name', 'Student ID' : 'student_id', 'name' : 'student_name'}, inplace=True)
ed_df = pd.merge(school_df, student_df, on='school_name')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-0920e7bed75a> in <module>()
#       1 SchoolFile = os.path.join('04 Pandas', 'PyCitySchools', 'raw_data','schools_complete.csv')
#       2 StudentFile = os.path.join('04 Pandas', 'PyCitySchools', 'raw_data','students_complete.csv')
# ----> 3 school_df = pd.read_csv(SchoolFile)
#       4 student_df = pd.read_csv(StudentFile)
#       5 school_df.rename(columns={'name': 'school_name', 'School ID' : 'school_id'}, inplace=True)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'04 Pandas/PyCitySchools/raw_data/schools_complete.csv' does not exist

# %%
os.getcwd()
# Out:
# '/Users/christopher/Documents/Education/Coding Bootcamp/Git/Data_Class/CodingHomework/HW_04'

# %%
cd ..
# Out:
# /Users/christopher/Documents/Education/Coding Bootcamp/Git/Data_Class/CodingHomework

# %%
SchoolFile = os.path.join('04 Pandas', 'PyCitySchools', 'raw_data','schools_complete.csv')
StudentFile = os.path.join('04 Pandas', 'PyCitySchools', 'raw_data','students_complete.csv')
school_df = pd.read_csv(SchoolFile)
student_df = pd.read_csv(StudentFile)
school_df.rename(columns={'name': 'school_name', 'School ID' : 'school_id'}, inplace=True)
student_df.rename(columns={'school': 'school_name', 'Student ID' : 'student_id', 'name' : 'student_name'}, inplace=True)
ed_df = pd.merge(school_df, student_df, on='school_name')
ed_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-fc546a92b8a1> in <module>()
#       1 SchoolFile = os.path.join('04 Pandas', 'PyCitySchools', 'raw_data','schools_complete.csv')
#       2 StudentFile = os.path.join('04 Pandas', 'PyCitySchools', 'raw_data','students_complete.csv')
# ----> 3 school_df = pd.read_csv(SchoolFile)
#       4 student_df = pd.read_csv(StudentFile)
#       5 school_df.rename(columns={'name': 'school_name', 'School ID' : 'school_id'}, inplace=True)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'04 Pandas/PyCitySchools/raw_data/schools_complete.csv' does not exist

# %%
cd ../../..
# Out:
# /Users/christopher/Documents/Education/Coding Bootcamp

# %%
cd Homework
# Out:
# /Users/christopher/Documents/Education/Coding Bootcamp/Homework

# %%
SchoolFile = os.path.join('04 Pandas', 'PyCitySchools', 'raw_data','schools_complete.csv')
StudentFile = os.path.join('04 Pandas', 'PyCitySchools', 'raw_data','students_complete.csv')
school_df = pd.read_csv(SchoolFile)
student_df = pd.read_csv(StudentFile)
school_df.rename(columns={'name': 'campus', 'School ID' : 'school_id'}, inplace=True)
student_df.rename(columns={'school': 'campus', 'Student ID' : 'student_id', 'name' : 'student_name'}, inplace=True)
ed_df = pd.merge(school_df, student_df, on='campus')
ed_df
# Out:
#        school_id              campus      type  size   budget  student_id  \
# 0              0   Huang High School  District  2917  1910635           0
# 1              0   Huang High School  District  2917  1910635           1
# 2              0   Huang High School  District  2917  1910635           2
# 3              0   Huang High School  District  2917  1910635           3
# 4              0   Huang High School  District  2917  1910635           4
# 5              0   Huang High School  District  2917  1910635           5
# 6              0   Huang High School  District  2917  1910635           6
# 7              0   Huang High School  District  2917  1910635           7
# 8              0   Huang High School  District  2917  1910635           8
# 9              0   Huang High School  District  2917  1910635           9
# 10             0   Huang High School  District  2917  1910635          10
# 11             0   Huang High School  District  2917  1910635          11
# 12             0   Huang High School  District  2917  1910635          12
# 13             0   Huang High School  District  2917  1910635          13
# 14             0   Huang High School  District  2917  1910635          14
# 15             0   Huang High School  District  2917  1910635          15
# 16             0   Huang High School  District  2917  1910635          16
# 17             0   Huang High School  District  2917  1910635          17
# 18             0   Huang High School  District  2917  1910635          18
# 19             0   Huang High School  District  2917  1910635          19
# 20             0   Huang High School  District  2917  1910635          20
# 21             0   Huang High School  District  2917  1910635          21
# 22             0   Huang High School  District  2917  1910635          22
# 23             0   Huang High School  District  2917  1910635          23
# 24             0   Huang High School  District  2917  1910635          24
# 25             0   Huang High School  District  2917  1910635          25
# 26             0   Huang High School  District  2917  1910635          26
# 27             0   Huang High School  District  2917  1910635          27
# 28             0   Huang High School  District  2917  1910635          28
# 29             0   Huang High School  District  2917  1910635          29
# ...          ...                 ...       ...   ...      ...         ...
# 39140         14  Thomas High School   Charter  1635  1043130       39140
# 39141         14  Thomas High School   Charter  1635  1043130       39141
# 39142         14  Thomas High School   Charter  1635  1043130       39142
# 39143         14  Thomas High School   Charter  1635  1043130       39143
# 39144         14  Thomas High School   Charter  1635  1043130       39144
# 39142  Deborah Higgins DDS      F  10th             96          83
# 39143       Steven Jackson      M  11th             71          93
# 39144     Cristian Webster      M  12th             77          87
# 39145           Audrey Fry      F  10th             94          74
# 39146      Michael Carroll      M   9th             69          95
# 39147      Raymond Hawkins      M  10th             88          81
# 39148   Christopher Wilson      M  10th             89          89
# 39149      Glenda Fletcher      F  11th             82          93
# 39150    Jennifer Hamilton      F  11th             80          75
# 39151     Shannon Williams      F  10th             84          73
# 39152           Lori Moore      F   9th             98          84
# 39153      William Hubbard      M   9th             80          75
# 39154      Bradley Johnson      M  12th             91          71
# 39155          John Brooks      M  10th             92          98
# 39156  Stephanie Contreras      F  11th             79          95
# 39157     Kristen Gonzalez      F   9th             79          94
# 39158        Kari Holloway      F  10th             87          90
# 39159     Kimberly Cabrera      F  11th             85          72
# 39160         Katie Weaver      F  11th             89          86
# 39161          April Reyes      F  10th             70          84
# 39162          Derek Weeks      M  12th             94          77
# 39163           John Reese      M  11th             90          75
# 39164       Joseph Anthony      M   9th             97          76
# 39165         Donna Howard      F  12th             99          90
# 39166            Dawn Bell      F  10th             95          70
# 39167       Rebecca Tanner      F   9th             73          84
# 39168         Desiree Kidd      F  10th             99          90
# 39169      Carolyn Jackson      F  11th             95          75
#
# [39170 rows x 11 columns]

# %%
ed_df['budget'] = ed_df['budget'].astype('float64')

# %%
ed_df.dtypes
# Out:
# school_id          int64
# campus            object
# type              object
# size               int64
# budget           float64
# student_id         int64
# student_name      object
# gender            object
# grade             object
# reading_score      int64
# math_score         int64
# dtype: object

# %%
ed_df.mean('budget')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-a80ebbbdfcad> in <module>()
# ----> 1 ed_df.mean('budget')
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    6340                                       skipna=skipna)
#    6341         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 6342                             numeric_only=numeric_only)
#    6343
#    6344     return set_function_name(stat_func, name, cls)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    5045     def _reduce(self, op, name, axis=0, skipna=True, numeric_only=None,
#    5046                 filter_type=None, **kwds):
# -> 5047         axis = self._get_axis_number(axis)
#    5048
#    5049         def f(x):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in _get_axis_number(self, axis)
#     351                 pass
#     352         raise ValueError('No axis named {0} for object type {1}'
# --> 353                          .format(axis, type(self)))
#     354
#     355     def _get_axis_name(self, axis):
#
# ValueError: No axis named budget for object type <class 'pandas.core.frame.DataFrame'>

# %%
ed_df['budget'].mean()
# Out:
# 2117240.989481746

# %%
TD_ed_df = ed_df.loc[ed_df['type'] == 'District', : ]

# %%
TD_ed_df
# Out:
#        school_id             campus      type  size     budget  student_id  \
# 0              0  Huang High School  District  2917  1910635.0           0
# 1              0  Huang High School  District  2917  1910635.0           1
# 2              0  Huang High School  District  2917  1910635.0           2
# 3              0  Huang High School  District  2917  1910635.0           3
# 4              0  Huang High School  District  2917  1910635.0           4
# 5              0  Huang High School  District  2917  1910635.0           5
# 6              0  Huang High School  District  2917  1910635.0           6
# 7              0  Huang High School  District  2917  1910635.0           7
# 8              0  Huang High School  District  2917  1910635.0           8
# 3       Dr. Richard Scott      M  12th             67          58
# 4              Bonnie Ray      F   9th             97          84
# 5           Bryan Miranda      M   9th             94          94
# 6           Sheena Carter      F  11th             82          80
# 7            Nicole Baker      F  12th             96          69
# 8            Michael Roth      M  10th             95          87
# 9          Matthew Greene      M  10th             96          84
# 10       Andrew Alexander      M  10th             90          70
# 11          Daniel Cooper      M  10th             78          77
# 12        Brittney Walker      F   9th             64          79
# 13           William Long      M   9th             71          79
# 14           Tammy Hebert      F  10th             85          67
# 15      Dr. Jordan Carson      M  11th             94          88
# 16          Donald Zamora      M   9th             88          55
# 17      Kimberly Santiago      F   9th             74          75
# 18          Kevin Stevens      M   9th             64          69
# 19           Brandi Lyons      F   9th             89          80
# 20             Lisa Davis      F  10th             91          89
# 21          Kristen Lopez      F  10th             90          77
# 22       Kimberly Stewart      F  11th             99          84
# 23     Christopher Parker      M   9th             81          68
# 24       Chelsea Griffith      F  11th             85          73
# 25           Cesar Morris      M   9th             92          70
# 26         Melanie Decker      F   9th             63          85
# 27         Tracey Oconnor      F  10th             80          58
# 28            Kelly James      F  11th             73          55
# 29           Nicole Brown      F  12th             90          88
# ...                   ...    ...   ...            ...         ...
# 37505        Jason Wagner      M  12th             97          80
# 37506     Maurice Nielsen      M  12th             76          66
# 37507        James Turner      M  12th             73          74
# 37508          Larry Pope      M   9th             74          61
# 37509       Robert Martin      M  12th             80          67
# 37510      Darius Jimenez      M  12th             89          82
# 37511       Daniel Turner      M  10th             68          58
# 37512         Lauren Cook      F   9th             84          72
# 37513    Wayne Washington      M  11th             79          63
# 37514        Leslie White      F  12th             80          73
# 37515       Maria Andrade      F  12th             69          87
# 37516       Tracy Sanchez      F  11th             76          75
# 37517       Kayla Johnson      F   9th             71          80
# 37518      Daniel Andrews      M   9th             89          98
# 37519       Ruben Ramirez      M  12th             84          65
# 37520   Benjamin Odonnell      M  11th             63          74
# 37521      Meredith Tapia      F   9th             77          78
# 37522        Ricky Little      M  12th             90          68
# 37523  Rebecca Valenzuela      F  10th             90          84
# 37524     Carrie Fletcher      F   9th             84          72
# 37525      Steven Summers      M   9th             71          71
# 37526        Jon Santiago      M  10th             98          56
# 37527  Thomas Christensen      M   9th             98          60
# 37528      Nicholas Perry      M  11th             83          83
# 37529  Victoria Rodriguez      F  11th             76          69
# 37530      William Rivera      M   9th             63          59
# 37531        Bernard Reid      M   9th             94          80
# 37532         Dawn Sawyer      F  12th             91          66
# 37533        Thomas Knapp      M  12th             75          70
# 37534      Melissa Porter      F   9th             76          84
#
# [26976 rows x 11 columns]

# %%
TD_ed_df['budget'].mean()
# Out:
# 2611174.8952031434

# %%
C_ed_df = ed_df.loc[ed_df['type'] == 'Charter', : ]

# %%
C_ed_df
# Out:
#        school_id               campus     type  size     budget  student_id  \
# 5866           2  Shelton High School  Charter  1761  1056600.0        5866
# 5867           2  Shelton High School  Charter  1761  1056600.0        5867
# 39159     Kimberly Cabrera      F  11th             85          72
# 39160         Katie Weaver      F  11th             89          86
# 39161          April Reyes      F  10th             70          84
# 39162          Derek Weeks      M  12th             94          77
# 39163           John Reese      M  11th             90          75
# 39164       Joseph Anthony      M   9th             97          76
# 39165         Donna Howard      F  12th             99          90
# 39166            Dawn Bell      F  10th             95          70
# 39167       Rebecca Tanner      F   9th             73          84
# 39168         Desiree Kidd      F  10th             99          90
# 39169      Carolyn Jackson      F  11th             95          75
#
# [12194 rows x 11 columns]

# %%
C_ed_df['budget'].mean()
# Out:
# 1024542.855912744

# %%
TD_ed_df['reading_score'].mean()
# Out:
# 80.96248517200475

# %%
C_ed_df['reading_score'].mean()
# Out:
# 83.90282105953747

# %%
TD_ed_df['math_score'].mean()
# Out:
# 76.98702550415184

# %%
C_ed_df['math_score'].mean()
# Out:
# 83.40618336886993

# %%
TD_ed_df['budget'].mean()
# Out:
# 2611174.8952031434

# %%
TD_ed_df['student_id'].count()
# Out:
# 26976

# %%
TD_ed_df['reading_score'].min()
# Out:
# 63

# %%
ed_df_passing = ed_df['reading_score']<= 70

# %%
ed_df_passing
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12        True
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18        True
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26        True
# 27       False
# 28       False
# 29       False
#          ...
# 39140    False
# 39141    False
# 39142    False
# 39143    False
# 39144    False
# 39145    False
# 39146     True
# 39147    False
# 39148    False
# 39149    False
# 39150    False
# 39151    False
# 39152    False
# 39153    False
# 39154    False
# 39155    False
# 39156    False
# 39157    False
# 39158    False
# 39159    False
# 39160    False
# 39161     True
# 39162    False
# 39163    False
# 39164    False
# 39165    False
# 39166    False
# 39167    False
# 39168    False
# 39169    False
# Name: reading_score, Length: 39170, dtype: bool

# %%
reading_passing_rate = round(ed_df["student_id"].sum()/ed_df_passing, 2)

# %%
reading_passing_rate
# Out:
# 0        7.671249e+08
# 1                 inf
# 2                 inf
# 3        7.671249e+08
# 4                 inf
# 5                 inf
# 6                 inf
# 7                 inf
# 8                 inf
# 9                 inf
# 10                inf
# 11                inf
# 12       7.671249e+08
# 13                inf
# 14                inf
# 15                inf
# 16                inf
# 17                inf
# 18       7.671249e+08
# 19                inf
# 20                inf
# 21                inf
# 22                inf
# 23                inf
# 24                inf
# 25                inf
# 26       7.671249e+08
# 27                inf
# 28                inf
# 29                inf
#              ...
# 39140             inf
# 39141             inf
# 39142             inf
# 39143             inf
# 39144             inf
# 39145             inf
# 39146    7.671249e+08
# 39147             inf
# 39148             inf
# 39149             inf
# 39150             inf
# 39151             inf
# 39152             inf
# 39153             inf
# 39154             inf
# 39155             inf
# 39156             inf
# 39157             inf
# 39158             inf
# 39159             inf
# 39160             inf
# 39161    7.671249e+08
# 39162             inf
# 39163             inf
# 39164             inf
# 39165             inf
# 39166             inf
# 39167             inf
# 39168             inf
# 39169             inf
# Name: reading_score, Length: 39170, dtype: float64
